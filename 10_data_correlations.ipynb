# %%
# 🔗 Data Correlations in Pandas

# Correlation is a statistical measure that shows how two numerical variables are related.

# In Pandas, we use `.corr()` to calculate the correlation between columns.
# - Values range from **-1** to **+1**
#   - `+1` = strong positive correlation
#   - `0` = no correlation
#   - `-1` = strong negative correlation

# %%
import pandas as pd

data = pd.read_csv('data.csv')
df = pd.DataFrame(data)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
## 🧠 Calculate Correlation Between All Numeric Columns
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922721
# Pulse    -0.155408  1.000000  0.786535  0.025120
# Maxpulse  0.009403  0.786535  1.000000  0.203814
# Calories  0.922721  0.025120  0.203814  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

## 📊 Visualizing Correlation Matrix with Seaborn
# ✅ Use `.corr()` to measure relationships between numeric columns  
# ✅ Use heatmaps to visualize strength and direction of correlations  
# ✅ Useful in feature selection and data analysis

# %%
# 📈 Pandas - Plotting

# Pandas has built-in support for plotting through the `.plot()` method,  
# powered by **Matplotlib** under the hood.

# You can quickly visualize trends, distributions, and comparisons.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot()

plt.show()

# %%
# Skatter Plot
df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %%
df["Duration"].plot(kind = 'hist')

plt.show()

# %%
# ✅ Use `.plot(kind="...")` to visualize DataFrames  
# ✅ Common kinds: `"line"`, `"bar"`, `"pie"`, `"hist"`, `"box"`  
# ✅ Combine with `matplotlib.pyplot` for more control

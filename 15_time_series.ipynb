# %%
# ⏰ Working with Time Series in Pandas

# Pandas provides powerful tools for working with **date/time** data,  
# including parsing, indexing, resampling, and time-based filtering.

# %%
import pandas as pd

data = {
    "Date": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05"],
    "Sales": [100, 120, 90, 140, 130]
}

df = pd.DataFrame(data)

# Convert 'Date' column to datetime
df["Date"] = pd.to_datetime(df["Date"])
df
# Out:
#         Date  Sales
# 0 2024-01-01    100
# 1 2024-01-02    120
# 2 2024-01-03     90
# 3 2024-01-04    140
# 4 2024-01-05    130

# %%
## 📅 Set the datetime column as the DataFrame index
df.set_index("Date", inplace=True)
df
# Out:
#             Sales
# Date
# 2024-01-01    100
# 2024-01-02    120
# 2024-01-03     90
# 2024-01-04    140
# 2024-01-05    130

# %%
## 📈 Plot time-based data

import matplotlib.pyplot as plt

df.plot(title="Sales Over Time", marker="o")
plt.ylabel("Sales")
plt.show()

# %%
## 🔍 Filter rows using a date range

df["2024-01-02":"2024-01-04"]
# Out:
#             Sales
# Date
# 2024-01-02    120
# 2024-01-03     90
# 2024-01-04    140

# %%
# Example: Resample daily data into weekly sums

df.resample("W").sum()
# Out:
#             Sales
# Date
# 2024-01-07    580

# %%
## 🧪 Create a custom date range

pd.date_range(start="2024-01-01", periods=5, freq="D")
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# ✅ Use `pd.to_datetime()` to convert columns to datetime  
# ✅ Use `set_index()` for time-based indexing  
# ✅ Use slicing, filtering, and `resample()` for powerful time operations
